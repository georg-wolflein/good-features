# %%
from torch.utils.data import DataLoader
import torch
import matplotlib.pyplot as plt
from torchvision import transforms as T

from histaug.data import SlidesDataset
from histaug.augmentations import load_augmentations

# %%
torch.manual_seed(42)

augmentations = load_augmentations()

ds = SlidesDataset("/data/shiprec/TCGA-BRCA/", batch_size=1)

slide_ds = ds[0]
patch, coords, norm_patch = slide_ds[len(slide_ds) // 2]
plt.imshow(ds.inverse_transform(patch).squeeze(0))
# Out:
# 2023-12-02 16:44:54.299 | INFO     | histaug.augmentations:__init__:30 - Fitting Macenko normalizer to /app/normalization_template.jpg
