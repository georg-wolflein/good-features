# %%
import pandas as pd
import torch
from typing import NamedTuple, Dict
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from histaug.utils import load_features
from histaug.metrics import compute_dists, SIMILARITY_METRICS
from histaug.feature_extractors import FEATURE_EXTRACTORS

# %%
models = FEATURE_EXTRACTORS.keys()
# models = ["ctranspath", "swin", "resnet50"]
models = ["ctranspath", "swin"]

features_by_model = {model: load_features(f"/data/histaug/results/kather100k/{model}.zarr") for model in tqdm(models)}
# Out:
# 100%|██████████| 2/2 [00:34<00:00, 17.04s/it]

# %%
metric = "cosine"
# metric = "euclidean"
metric = "manhattan"
metric = "mahalanobis"


class LoadedFeaturesAndDists(NamedTuple):
    feats: np.ndarray
    feats_augs: Dict[str, np.ndarray]
    labels: np.ndarray
    files: np.ndarray
    dists: pd.DataFrame


N = 1000

features_and_dists_by_model = {
    model: LoadedFeaturesAndDists(
        feats=f.feats[:N],
        feats_augs=f.feats_augs[:N],
        labels=f.labels[:N],
        files=f.files[:N],
        dists=compute_dists(f.feats, f.feats_augs, metric=metric),
    )
    for model, f in tqdm(features_by_model.items())
}


# features_and_dists_by_model = {
#     model: LoadedFeaturesAndDists(
#         feats=f.feats,
#         feats_augs=f.feats_augs,
#         labels=f.labels,
#         files=f.files,
#         dists=compute_dists(f.feats, f.feats_augs, metric=metric),
#     )
#     for model, f in tqdm(features_by_model.items())
# }
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /app/analyze_features_kather100k.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     dists: pd.DataFrame
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> N = 1000
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> features_and_dists_by_model = {
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     model: LoadedFeaturesAndDists(
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>         feats=f.feats[:N],
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>         feats_augs=f.feats_augs[:N],
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>         labels=f.labels[:N],
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>         files=f.files[:N],
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>         dists=compute_dists(f.feats, f.feats_augs, metric=metric),
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     )
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>     for model, f in tqdm(features_by_model.items())
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> }
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> # features_and_dists_by_model = {
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> #     model: LoadedFeaturesAndDists(
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a> #         feats=f.feats,
#    (...)
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=36'>37</a> #     for model, f in tqdm(features_by_model.items())
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a> # }
#
# /app/analyze_features_kather100k.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     dists: pd.DataFrame
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> N = 1000
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> features_and_dists_by_model = {
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     model: LoadedFeaturesAndDists(
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>         feats=f.feats[:N],
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>         feats_augs=f.feats_augs[:N],
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>         labels=f.labels[:N],
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>         files=f.files[:N],
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>         dists=compute_dists(f.feats, f.feats_augs, metric=metric),
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     )
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>     for model, f in tqdm(features_by_model.items())
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> }
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> # features_and_dists_by_model = {
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> #     model: LoadedFeaturesAndDists(
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a> #         feats=f.feats,
#    (...)
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=36'>37</a> #     for model, f in tqdm(features_by_model.items())
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a> # }
#
# TypeError: unhashable type: 'slice'

# %%
mean_dist_by_class_by_model = {
    model: feats.dists[(feats.labels != "BACK") & (feats.dists["Macenko"] != 1.0)].mean()
    for model, feats in features_and_dists_by_model.items()
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /app/analyze_features_kather100k.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> mean_dist_by_class_by_model = {
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     model: feats.dists[(feats.labels != "BACK") & (feats.dists["Macenko"] != 1.0)].mean()
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     for model, feats in features_and_dists_by_model.items()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/analyze_features_kather100k.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> }
#
# NameError: name 'features_and_dists_by_model' is not defined

# %%
def compute_baseline_similarity(feats: torch.Tensor, metric: str) -> float:
    """Compute similarity between features and randomly permuted features."""
    feats_perm = feats[torch.randperm(feats.shape[0])]
    return SIMILARITY_METRICS[metric](feats, feats_perm).mean().item()


baseline_similarity_by_model = {
    model: compute_baseline_similarity(torch.from_numpy(f.feats), metric=metric)
    for model, f in features_by_model.items()
}
baseline_similarity_by_model
# Out:
# {'ctranspath': 77.11526489257812,
#  'retccl': 35.88531494140625,
#  'resnet50': 309.08819580078125,
#  'swin': 399.38623046875}

# %%
df = pd.DataFrame(mean_dist_by_class_by_model).sort_values(by="ctranspath", ascending=False)

plt.figure(figsize=(10, 5))
plt.title(f"Mean distance by class by model ({metric}) (ignoring BACK class)")

colors = plt.rcParams["axes.prop_cycle"].by_key()["color"]
model_colors = {model: colors[i % len(colors)] for i, model in enumerate(df.columns)}

# Grouped bar chart
w = 0.8 / len(df.columns)
for i, (model, d) in enumerate(df.items()):
    b = plt.bar(x=np.arange(len(d)) + i * w, height=d, width=w, label=model, color=model_colors[model])

# Show baseline similarity as horizontal lines
for model, baseline_similarity in baseline_similarity_by_model.items():
    plt.axhline(baseline_similarity, linestyle="--", color=model_colors[model])

plt.xticks(np.arange(len(d)) + w / 2, d.index, rotation=90)

plt.legend(loc="upper right")
