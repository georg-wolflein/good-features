# %%
import pandas as pd
from pathlib import Path
import re

COHORT = "TCGA-BRCA"
COHORT = "CPTAC-BRCA"
COHORT = "CPTAC-CRC"
METADATA_DIR = Path("/metadata")

TCGA_PATIENT_ID_PATTERN = r"^[\w]+:(\w+-\w+-\w+)-\d+$"
CPTAC_PATIENT_ID_PATTERN = r"^[\w]+:[A-Z]+(\d[\w]*)$"
SAMPLE_MATRIX_PATIENT_ID_PATTERN = re.compile(
    TCGA_PATIENT_ID_PATTERN if COHORT.upper().startswith("TCGA") else CPTAC_PATIENT_ID_PATTERN
)
CLINICAL_PATIENT_ID_PATTERN = re.compile(r"(.+)" if COHORT.upper().startswith("TCGA") else r"[A-Z]+(\d[\w]*)")


if COHORT == "TCGA-BRCA":
    CLINICAL_TARGETS = {"Subtype": "subtype"}
    REPLACE_CATEGORICAL_VALUES = {
        "subtype": {
            "BRCA_LumA": "LumA",
            "BRCA_LumB": "LumB",
            "BRCA_Her2": "Her2",
            "BRCA_Basal": "Basal",
            "BRCA_Normal": "Normal",
        }
    }
elif COHORT == "CPTAC-BRCA":
    CLINICAL_TARGETS = {"PAM50": "subtype"}
    REPLACE_CATEGORICAL_VALUES = {
        "subtype": {
            "LumA": "LumA",
            "LumB": "LumB",
            "Her2": "Her2",
            "Basal": "Basal",
            "Normal-like": "Normal",
        }
    }
elif COHORT == "CPTAC-CRC":
    CLINICAL_TARGETS = {"MSI Status": "msi"}
    REPLACE_CATEGORICAL_VALUES = {
        "msi": {
            "MSI-H": "MSI-H",
            "MSS": "MSS",
        }
    }


sample_matrix_file = METADATA_DIR / f"{COHORT}_sample_matrix.tsv"
clinical_file = METADATA_DIR / f"{COHORT}_clinical.tsv"
clini_table = METADATA_DIR / f"{COHORT}_CLINI.csv"  # output file

# %%
dfc
# Out:
#             Study ID Patient ID Sample ID   Age        Cancer Type  \
# 0    coad_cptac_2019    01CO001   01CO001  61.0  Colorectal Cancer
# 1    coad_cptac_2019    01CO005   01CO005  70.0  Colorectal Cancer
# 2    coad_cptac_2019    01CO006   01CO006  75.0  Colorectal Cancer
# 3    coad_cptac_2019    01CO008   01CO008  54.0  Colorectal Cancer
# 4    coad_cptac_2019    01CO013   01CO013  58.0  Colorectal Cancer
# ..               ...        ...       ...   ...                ...
# 105  coad_cptac_2019    21CO007   21CO007  50.0  Colorectal Cancer
# 106  coad_cptac_2019    22CO004   22CO004  52.0  Colorectal Cancer
# 107  coad_cptac_2019    22CO006   22CO006  57.0  Colorectal Cancer
# 108  coad_cptac_2019    24CO005   24CO005  41.0  Colorectal Cancer
# 109  coad_cptac_2019    27CO004   27CO004  51.0  Colorectal Cancer
#
#      Cancer Type Detailed  Copy Number  Disease Free (Months)  \
# 0    Colon Adenocarcinoma            1                   32.0
# 1    Colon Adenocarcinoma            1                    NaN
# 2    Colon Adenocarcinoma            1                   29.0
# 3    Colon Adenocarcinoma            1                    NaN
# 4    Colon Adenocarcinoma            1                   13.0
# ..                    ...          ...                    ...
# 105  Colon Adenocarcinoma            1                    NaN
# 106  Colon Adenocarcinoma            1                   29.0
# 107  Colon Adenocarcinoma            1                   22.0
# 108  Colon Adenocarcinoma            1                    NaN
# 109  Colon Adenocarcinoma            1                   36.0
#
#        Disease Free Status  Fraction Genome Altered  ...      Primary Site  \
# 0            0:DiseaseFree                   0.1486  ...     Sigmoid Colon
# 1            0:DiseaseFree                   0.5642  ...     Sigmoid Colon
# 2    1:Recurred/Progressed                   0.0105  ...   Ascending Colon
# 3    1:Recurred/Progressed                   0.0515  ...  Descending Colon
# 4            0:DiseaseFree                   0.1624  ...     Sigmoid Colon
# ..                     ...                      ...  ...               ...
# 105                    NaN                   0.4457  ...     Sigmoid Colon
# 106          0:DiseaseFree                   0.3811  ...     Sigmoid Colon
# 107  1:Recurred/Progressed                   0.0055  ...   Ascending Colon
# 108                    NaN                   0.3783  ...     Sigmoid Colon
# 109          0:DiseaseFree                   0.2141  ...             Cecum
#
#     Protein  Number of Samples Per Patient  Sequenced     Sex Somatic Status  \
# 0         0                              1          1    Male        Matched
# 1         1                              1          1  Female        Matched
# 2         1                              1          1  Female        Matched
# 3         1                              1          1  Female        Matched
# 4         1                              1          1    Male        Matched
# ..      ...                            ...        ...     ...            ...
# 105       1                              1          1    Male        Matched
# 106       1                              1          1    Male        Matched
# 107       1                              1          1  Female        Matched
# 108       0                              1          1  Female        Matched
# 109       1                              1          1  Female        Matched
#
#      Specimen Preservation Method Cancer Stage  TMB (nonsynonymous)  \
# 0                   Frozen Tissue    Stage III             2.566667
# 1                   Frozen Tissue     Stage II             4.366667
# 2                   Frozen Tissue    Stage III             2.700000
# 3                   Frozen Tissue     Stage II             5.166667
# 4                   Frozen Tissue      Stage I             2.633333
# ..                            ...          ...                  ...
# 105                 Frozen Tissue     Stage IV             4.466667
# 106                 Frozen Tissue     Stage II             2.866667
# 107                 Frozen Tissue    Stage III            34.933333
# 108                           NaN    Stage III             3.200000
# 109                 Frozen Tissue    Stage III             3.866667
#
#            Tumor Site
# 0       Sigmoid Colon
# 1       Sigmoid Colon
# 2     Ascending Colon
# 3    Descending Colon
# 4       Sigmoid Colon
# ..                ...
# 105     Sigmoid Colon
# 106     Sigmoid Colon
# 107   Ascending Colon
# 108     Sigmoid Colon
# 109             Cecum
#
# [110 rows x 38 columns]

# %%
dfc = pd.read_csv(clinical_file, sep="\t")
dfc["PATIENT"] = dfc["Patient ID"].apply(lambda x: CLINICAL_PATIENT_ID_PATTERN.match(x).group(1))
dfc.set_index("PATIENT", inplace=True)
dfc.rename(columns=CLINICAL_TARGETS, inplace=True)
dfc = dfc[list(CLINICAL_TARGETS.values())]
# dfc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /app/helpers/clini.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/helpers/clini.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> dfc = pd.read_csv(clinical_file, sep="\t")
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/helpers/clini.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> dfc["PATIENT"] = dfc["Patient ID"].apply(lambda x: CLINICAL_PATIENT_ID_PATTERN.match(x).group(1))
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/helpers/clini.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> dfc.set_index("PATIENT", inplace=True)
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/helpers/clini.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> dfc.rename(columns=CLINICAL_TARGETS, inplace=True)
#
# File /app/env/lib/python3.9/site-packages/pandas/core/series.py:4758, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4756     dtype: float64
#    4757     """
# -> 4758     return SeriesApply(
#    4759         self,
#    4760         func,
#    4761         convert_dtype=convert_dtype,
#    4762         by_row=by_row,
#    4763         args=args,
#    4764         kwargs=kwargs,
#    4765     ).apply()
#
# File /app/env/lib/python3.9/site-packages/pandas/core/apply.py:1201, in SeriesApply.apply(self)
#    1198     return self.apply_compat()
#    1200 # self.func is Callable
# -> 1201 return self.apply_standard()
#
# File /app/env/lib/python3.9/site-packages/pandas/core/apply.py:1281, in SeriesApply.apply_standard(self)
#    1275 # row-wise access
#    1276 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1277 # we need to give `na_action="ignore"` for categorical data.
#    1278 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1279 #  Categorical (GH51645).
#    1280 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1281 mapped = obj._map_values(
#    1282     mapper=curried, na_action=action, convert=self.convert_dtype
#    1283 )
#    1285 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1286     warnings.warn(
#    1287         "Returning a DataFrame from Series.apply when the supplied function "
#    1288         "returns a Series is deprecated and will be removed in a future "
#    (...)
#    1291         stacklevel=find_stack_level(),
#    1292     )  # GH52116
#
# File /app/env/lib/python3.9/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /app/env/lib/python3.9/site-packages/pandas/core/algorithms.py:1812, in map_array(arr, mapper, na_action, convert)
#    1810 values = arr.astype(object, copy=False)
#    1811 if na_action is None:
# -> 1812     return lib.map_infer(values, mapper, convert=convert)
#    1813 else:
#    1814     return lib.map_infer_mask(
#    1815         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1816     )
#
# File lib.pyx:2917, in pandas._libs.lib.map_infer()
#
# /app/helpers/clini.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/helpers/clini.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> dfc = pd.read_csv(clinical_file, sep="\t")
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/helpers/clini.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> dfc["PATIENT"] = dfc["Patient ID"].apply(lambda x: CLINICAL_PATIENT_ID_PATTERN.match(x).group(1))
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/helpers/clini.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> dfc.set_index("PATIENT", inplace=True)
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f67656f72672d68697374617567222c2273657474696e6773223a7b22686f7374223a227373683a2f2f646778227d7d/app/helpers/clini.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> dfc.rename(columns=CLINICAL_TARGETS, inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
df = pd.read_csv(sample_matrix_file, sep="\t")

id_col = "studyID:sampleId"

patient_id = df[id_col].apply(lambda x: SAMPLE_MATRIX_PATIENT_ID_PATTERN.match(x).group(1))
df["PATIENT"] = patient_id

# Check if there are duplicate values for a feature for a patient
dup = df.drop(columns=[id_col]).groupby("PATIENT").nunique() != 1
dup = dup.index[dup.any(axis=1)]

if len(dup) > 0:
    print(f"Found {len(dup)} patients with multiple values for a feature:")
    print(df[df["PATIENT"].isin(dup)])
    print("Dropping these patients.")
    df = df[~df["PATIENT"].isin(dup)]

df.drop(columns=[id_col, "Altered"], inplace=True)
df.set_index("PATIENT", inplace=True)
# df

# %%
print(
    "Unmatched:", len(set(dfc.index.values) - set(df.index.values)), len(set(df.index.values) - set(dfc.index.values))
)
# Out:
# Unmatched: 0 0

# %%
df = df.merge(dfc, left_index=True, right_index=True, how="outer")
for col, mapping in REPLACE_CATEGORICAL_VALUES.items():
    if unknown := set(df[col].unique()) ^ set(mapping.keys()):
        print(f"WARNING: unmapped values for {col}: {unknown}")
    df[col] = df[col].replace(mapping)

# %%
df.to_csv(clini_table)

# %%
df
# Out:
#          CDH1  TP53  PIK3CA subtype
# PATIENT
# 000814      0     1       0   Basal
# 001846      0     1       1   Basal
# 01BR001     0     1       0   Basal
# 01BR008     0     1       0   Basal
# 01BR009     0     0       0   Basal
# ...       ...   ...     ...     ...
# 21BR001     0     1       1    LumB
# 21BR002     0     0       1    LumA
# 21BR010     0     0       1    LumA
# 22BR005     0     1       1    LumA
# 22BR006     1     0       1    LumA
#
# [122 rows x 4 columns]
